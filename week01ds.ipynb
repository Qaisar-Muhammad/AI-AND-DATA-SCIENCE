# %%
import pandas as pd

# %%
df={
    "name":["ali","ayaz","muhammad","khan","farhan","ibrahim"],
    "marks":[43,56,77,88,34,99]
}
df=pd.DataFrame(df)
df
# Out:
#        name  marks
# 0       ali     43
# 1      ayaz     56
# 2  muhammad     77
# 3      khan     88
# 4    farhan     34
# 5   ibrahim     99

# %%
df["marks"].mean()
# Out:
# 66.16666666666667

# %%
df["marks"].mode()
# Out:
# 0    34
# 1    43
# 2    56
# 3    77
# 4    88
# 5    99
# Name: marks, dtype: int64

# %%
df["marks"].std()
# Out:
# 25.872121417979365

# %%
df.describe()
# Out:
#            marks
# count   6.000000
# mean   66.166667
# std    25.872121
# min    34.000000
# 25%    46.250000
# 50%    66.500000
# 75%    85.250000
# max    99.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['marks'])
# Out:
# (array([1., 1., 0., 1., 0., 0., 1., 0., 1., 1.]),
#  array([34. , 40.5, 47. , 53.5, 60. , 66.5, 73. , 79.5, 86. , 92.5, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
# privode a code for  boxplot
